# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from sklearn import preprocessing
#from sklearn.model_selection import train_test_split
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.metrics import accuracy_score
#from sklearn.model_selection import GridSearchCV

data = pd.read_csv('data.csv', low_memory=False)

# %%
data.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692     0818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# ...

# %%
data.shape
# Out:
# (2277779, 24)

# %%
data
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 0               55672688     2147
# 1               55672692     0818
# 2               55672693     9656
# 3               55672695     7412
# 4               55672697     4019
# 5               55672698     1328
# 6               55672699     0688
# 7               55672700     9604
# 8               55672703     2897
# 9               55672705     2602
# 10              55672708     2275
# 11              55672711     0696
# 12              55672712     2771
# 13              55672716     3197
# 14              55672718     3378
# 15              55672726     0124
# 16              55672727     4109
# 17              55672730     3219
# 18              55672738     1354
# 19              55672739     2774
# 20              55672740     2602
# 21              55672743     3457
# 22              55672751     2302
# 23              55672752     1949
# 24              55672754     8495
# 25              55672772     0106
# ...

# %%
data.groupby('INCIDENT_TYPE_DESC')['IM_INCIDENT_KEY'].size().sort_values(ascending=False)#.max()
# Out:
# INCIDENT_TYPE_DESC
# 300 - Rescue, EMS incident, other                               823378
# 651 - Smoke scare, odor of smoke                                148924
# 353 - Removal of victim(s) from stalled elevator                118264
# 710 - Malicious, mischievous false call, other                  117864
# 522 - Water or steam leak                                       108893
# 412 - Gas leak (natural gas or LPG)                             108362
# 735A - Unwarranted alarm/defective condition of alarm system    100500
# 113 - Cooking fire, confined to container                        87039
# 555 - Defective elevator, no occupants                           48147
# 736 - CO detector activation due to malfunction                  45982
# 322 - Motor vehicle accident with injuries                       45057
# 445 - Arcing, shorted electrical equipment                       37839
# 740A - Unnecessary alarm/construction activities                 31373
# ...

# %%
823378/2277779
# Out:
# 0.3614828304238471

# %%
data.groupby('IM_INCIDENT_KEY').nunique()['IM_INCIDENT_KEY'].size().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-55b7ec05d61e> in <module>()
# ----> 1 data.groupby('IM_INCIDENT_KEY').nunique()['IM_INCIDENT_KEY'].size().sort_values(ascending=False)
#
# TypeError: 'int' object is not callable

# %%
data.loc[data['BOROUGH_DESC'] == '3 - Staten Island']
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 23              55672752     1949
# 27              55672776     1022
# 33              55672802     4838
# 46              55672852     2776
# 54              55672879     1155
# 77              55672930     2859
# 78              55672935     0084
# 115             55673067     4010
# 117             55673070     3630
# 222             55673366     2254
# 241             55673404     0461
# 245             55673413     4755
# 275             55673474     0696
# 289             55673521     0030
# 306             55673558     3623
# 325             55673598     4594
# 467             55673950     3607
# 485             55673993     0798
# 488             55673998     4579
# 506             55674052     3415
# 518             55674072     3555
# 524             55674092     4334
# 585             55674202     0495
# 635             55674326     1024
# 671             55674395     4829
# 680             55674412     1537
# ...
